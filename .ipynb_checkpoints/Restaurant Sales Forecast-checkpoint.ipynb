# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
# read sales data into a dataframe
df = pd.read_csv('RestaurantSales.csv')

# %%
from datetime import datetime
# 
df['Date']=pd.to_datetime(df['Date'],infer_datetime_format=True)
df = df.set_index(['Date'])

# %%
df.head()
# Out:
#             Sales
# Date
# 2021-05-02  33100
# 2021-06-02  36800
# 2021-07-02  48600
# 2021-08-02  31900
# 2021-09-02  28500

# %%
df.shape
# Out:
# (92, 1)

# %%
df.size
# Out:
# 92

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 92 entries, 2021-05-02 to 2021-07-05
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   92 non-null     int64
# dtypes: int64(1)
# memory usage: 1.4 KB

# %%
df.describe()
# Out:
#               Sales
# count     92.000000
# mean   45223.369565
# std    18625.494242
# min    10000.000000
# 25%    30687.500000
# 50%    42400.000000
# 75%    57275.000000
# max    92200.000000

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Sales']);
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
df.Sales.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# determine rolling statistics
rol_mean =df.rolling(window=12).mean()
rol_std =df.rolling(window=12).std()

# %%
# plot rolling statistics
timeseries = df ['Sales']
timeseries.rolling(12).mean().plot(label='Rolling Mean')
timeseries.rolling(12).std().plot(label='Rolling Std')
plt.title('Rolling Mean & Standard Deviation')
timeseries.plot()
plt.legend()

# %%
plt.figure()
df.plot(figsize=(10, 6))
rol_mean.plot(figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# perform Dicket-Fuller test
from statsmodels.tsa.stattools import adfuller

print('Result od ADF test: ')
dftest = adfuller(df['Sales'],autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['ADF test statistic','p-value','#lags used','# of observation'])
for key,value in dftest[4].items():
    dfoutput['critical value (%s)' %key]=value
    
print(dfoutput)
# Out:
# Result od ADF test:
# ADF test statistic      -2.188368
# p-value                  0.210494
# #lags used               5.000000
# # of observation        86.000000
# critical value (1%)     -3.508783
# critical value (5%)     -2.895784
# critical value (10%)    -2.585038
# dtype: float64

# %%
# estimating trend
df_logScale = np.log(df)
#plt.plot(df_logScale)

# %%
movingAverage = df_logScale.rolling(window=12).mean()
movingSTD = df_logScale.rolling(window=12).std()

# %%
dataLogScaleMinusMovingAverage = df_logScale - movingAverage
# remove Nan values
dataLogScaleMinusMovingAverage.dropna(inplace=True)
dataLogScaleMinusMovingAverage.head()
# Out:
#                Sales
# Date
# 2021-02-16 -0.242413
# 2021-02-17 -0.657617
# 2021-02-18 -0.322746
# 2021-02-19 -0.060774
# 2021-02-20 -0.855901

# %%
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    # determine rolling statistics:
    movingAverage=timeseries.rolling(window=12).mean()
    movingSTD = timeseries.rolling(window=12).std()
    
    # perform dickey-fuller test
    print('Result: ')
    dftest=adfuller(timeseries['Sales'])
    dfoutput=pd.Series(dftest[0:4], index=['ADF test statistic','p-value','#lags used','# of observation'])
    for key,value in dftest[4].items():
        dfoutput['critical value (%s)' %key]=value
    
    print(dfoutput)

# %%
test_stationarity(dataLogScaleMinusMovingAverage)
# Out:
# Result:
# ADF test statistic      -2.630691
# p-value                  0.086818
# #lags used               5.000000
# # of observation        75.000000
# critical value (1%)     -3.520713
# critical value (5%)     -2.900925
# critical value (10%)    -2.587781
# dtype: float64

# %%
exponentialDecayiWeightedAverage = df_logScale.ewm(halflife=12, min_periods=0, adjust=True).mean()

# %%
dataLogScaleMinusMovingExponentialDecayAverage = df_logScale - exponentialDecayiWeightedAverage
test_stationarity(dataLogScaleMinusMovingExponentialDecayAverage)
# Out:
# Result:
# ADF test statistic      -2.367943
# p-value                  0.150989
# #lags used               5.000000
# # of observation        86.000000
# critical value (1%)     -3.508783
# critical value (5%)     -2.895784
# critical value (10%)    -2.585038
# dtype: float64

# %%
dataLogDiffShifting = df_logScale - df_logScale.shift()
dataLogDiffShifting.dropna(inplace=True)
test_stationarity(dataLogDiffShifting)
# Out:
# Result:
# ADF test statistic     -7.880028e+00
# p-value                 4.729976e-12
# #lags used              3.000000e+00
# # of observation        8.700000e+01
# critical value (1%)    -3.507853e+00
# critical value (5%)    -2.895382e+00
# critical value (10%)   -2.584824e+00
# dtype: float64

# %%
result = seasonal_decompose(df_logScale['Sales'], model='multiplicative', freq=30)
fig = plt.figure()
fig = result.plot()
fig.set_size_inches(14, 12)

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
# plot acf to identify parameter q
# ARIMA(p,d,q)

plot_acf(dataLogScaleMinusMovingAverage)

# %%
# plot_pacf to identify the value of p
plot_pacf(dataLogScaleMinusMovingAverage, linestyle='--',color='gray')

# %%
# ACF and PACF plots
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(dataLogScaleMinusMovingAverage, nlags=20)
lag_pacf = pacf(dataLogScaleMinusMovingAverage, nlags=20, method='ols')

# plot ACF
plt.subplot(121)
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(dataLogScaleMinusMovingAverage)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(dataLogScaleMinusMovingAverage)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')

# plot PACF
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(dataLogScaleMinusMovingAverage)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(dataLogScaleMinusMovingAverage)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %%
arima_model = ARIMA(df_logScale, order=(1, 1, 1))
arima_model_fit = arima_model.fit()
arima_model_fit.aic
# Out:
# /Users/khaiyra/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# /Users/khaiyra/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:585: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it is not'
# /Users/khaiyra/opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:581: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# ...

# %%
arimamodel = ARIMA(df_logScale.Sales, (1,1,1)).fit()

print(arimamodel.summary())
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.Sales   No. Observations:                   91
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                 -41.448
# Method:                       css-mle   S.D. of innovations              0.380
# Date:                Mon, 24 May 2021   AIC                             90.895
# Time:                        22:18:24   BIC                            100.939
# Sample:                             1   HQIC                            94.947
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            -0.0011      0.012     -0.087      0.931      -0.025       0.023
# ar.L1.D.Sales    -0.2650      0.137     -1.939      0.053      -0.533       0.003
# ma.L1.D.Sales    -0.6219      0.115     -5.392      0.000      -0.848      -0.396
# ...

# %%
predictions_ARIMA_diff = pd.Series(arimamodel.fittedvalues, copy=True)
print(predictions_ARIMA_diff.head())
# Out:
# Date
# 2021-06-02   -0.001054
# 2021-07-02   -0.065469
# 2021-08-02   -0.256553
# 2021-09-02    0.206892
# 2021-10-02    0.223158
# dtype: float64

# %%
# connvert to cumulative sum
predictions_ARIMA_diff_cumsum = predictions_ARIMA_diff.cumsum()
print(predictions_ARIMA_diff_cumsum.head())
# Out:
# Date
# 2021-06-02   -0.001054
# 2021-07-02   -0.066523
# 2021-08-02   -0.323076
# 2021-09-02   -0.116184
# 2021-10-02    0.106974
# dtype: float64

# %%
# results_ARIMA.plot_predict(1264)
x = arimamodel.forecast(steps=120)

# %%
x[1]
# Out:
# array([0.37975319, 0.38217255, 0.40438877, 0.41870132, 0.43415576,
#        0.44865691, 0.46281165, 0.47651835, 0.48984882, 0.50282416,
#        0.51547347, 0.5278196 , 0.5398835 , 0.55168365, 0.56323664,
#        0.57455737, 0.58565932, 0.59655469, 0.6072546 , 0.61776922,
#        0.62810785, 0.63827904, 0.64829067, 0.65815002, 0.66786384,
#        0.67743839, 0.68687949, 0.69619257, 0.7053827 , 0.71445463,
#        0.7234128 , 0.73226138, 0.74100431, 0.74964528, 0.75818778,
#        0.7666351 , 0.77499034, 0.78325647, 0.79143626, 0.79953237,
#        0.80754732, 0.8154835 , 0.82334318, 0.83112854, 0.83884165,
#        0.84648448, 0.85405892, 0.86156677, 0.86900975, 0.87638953,
#        0.88370768, 0.89096573, 0.89816512, 0.90530727, 0.91239351,
#        0.91942513, 0.92640338, 0.93332947, 0.94020453, 0.94702968,
#        0.95380599, 0.9605345 , 0.96721621, 0.97385207, 0.98044302,
#        0.98698995, 0.99349375, 0.99995524, 1.00637525, 1.01275456,
# ...

# %% [markdown]
# 1. I have no idea what I've done at the end part plus what is next
# 2. No comments to explain the lines of code
# 3. No inline documentation. Yet
